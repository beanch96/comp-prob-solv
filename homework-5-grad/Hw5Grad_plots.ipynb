# %%
import Psi_1s_func as fn 
import matplotlib.pyplot as plt
import numpy as np

#Diagonal Kinetic Energy Matrix Element (Kii)-Random sampling

# Parameters
np.random.seed(42)
L = 7  # Integration limits
n_points_list = [10**2, 10**3, 10**4, 10**5, 10**6, 10**7,10**8]  # Varying number of points
R=0  #No separation distance-diagonal elements

# Lists to store results
Kii_values = []
std_devs = []

# Monte Carlo integration loop for varying n_points
for n_points in n_points_list:
    Kii,std_dev=fn.random_integration(L,n_points,R)
    Kii_values.append(Kii)
    std_devs.append(std_dev)
    print(f"N = {n_points}, K_ii = {Kii}, Std Dev = {std_dev}")
   
# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(n_points_list, Kii_values, yerr=std_devs, fmt='o-', label='Estimated $K_{ii}$')
plt.xscale('log')
plt.xlabel('Number of Points Sampled (N)')
plt.ylabel('Kinetic Energy Matrix Element ($K_{ii}$)')
plt.title('Kinetic Energy Matrix Element ($K_{ii}$) integration\nRandom Sampling')
plt.grid()
plt.legend()
# Out:
# N = 100, K_ii = 0.3998428723300401, Std Dev = 0.42348376781415276
# N = 1000, K_ii = 0.3660428801877069, Std Dev = 0.19983199720968794
# N = 10000, K_ii = 0.2222944732334978, Std Dev = 0.059706213382657955
# N = 100000, K_ii = 0.43416906655518195, Std Dev = 0.044433579092380056
# N = 1000000, K_ii = 0.4954198968261311, Std Dev = 0.022201848951805627
# N = 10000000, K_ii = 0.4966138061886361, Std Dev = 0.007163033850810799
# N = 100000000, K_ii = 0.4973074516918407, Std Dev = 0.0026250275498757437

# %%
import Psi_1s_func as fn 
import matplotlib.pyplot as plt
import numpy as np

#Diagonal Kinetic Energy Matrix Element (Kii)-Importance sampling

# Parameters
np.random.seed(42)
L = 7  # Integration limits
n_points_list = [10**2, 10**3, 10**4, 10**5, 10**6, 10**7,10**8]  # Varying number of points
R=0  #No separation distance-diagonal elements

# Lists to store results
Kii_values = []
std_devs = []

# Monte Carlo integration loop for varying n_points
for n_points in n_points_list:
    Kii,std_dev=fn.important_integration(L,n_points,R)
    Kii_values.append(Kii)
    std_devs.append(std_dev)
    print(f"N = {n_points}, K_ii = {Kii}, Std Dev = {std_dev}")
   
# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(n_points_list, Kii_values, yerr=std_devs, fmt='o-', label='Estimated $K_{ii}$')
plt.xscale('log')
plt.xlabel('Number of Points Sampled (N)')
plt.ylabel('Kinetic Energy Matrix Element ($K_{ii}$)')
plt.title('Kinetic Energy Matrix Element ($K_{ii}$) integration\nImportance Sampling')
plt.grid()
plt.legend()
# Out:
# N = 100, K_ii = 0.5088152655358053, Std Dev = 0.2603228360067833
# N = 1000, K_ii = 0.505704601408411, Std Dev = 0.0766070043334148
# N = 10000, K_ii = 0.45695691125705007, Std Dev = 0.021074674385801385
# N = 100000, K_ii = 0.48823181738805865, Std Dev = 0.008051261373827242
# N = 1000000, K_ii = 0.4990010436455416, Std Dev = 0.0027551891239374743
# N = 10000000, K_ii = 0.4997806583881254, Std Dev = 0.0008747186058793402
# N = 100000000, K_ii = 0.49966092014026503, Std Dev = 0.00028327286757581435

# %%
import Psi_1s_func as fn 
import matplotlib.pyplot as plt
import numpy as np

#Off-diagonal Kinetic Energy Matrix Element (Kij)-random sampling

# Parameters
np.random.seed(42)
L = 7  # Integration limits
n_points_list = [10**2, 10**3, 10**4, 10**5, 10**6, 10**7,10**8]  # Varying number of points
R=1.4  #Rz=1.4

# Lists to store results
Kii_values = []
std_devs = []

# Monte Carlo integration loop for varying n_points
for n_points in n_points_list:
    Kii,std_dev=fn.important_integration(L,n_points,R)
    Kii_values.append(Kii)
    std_devs.append(std_dev)
    print(f"N = {n_points}, K_ii = {Kii}, Std Dev = {std_dev}")
   
# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(n_points_list, Kii_values, yerr=std_devs, fmt='o-', label='Estimated $K_{ii}$')
plt.xscale('log')
plt.xlabel('Number of Points Sampled (N)')
plt.ylabel('Kinetic Energy Matrix Element ($K_{ij}$)')
plt.title('Kinetic Energy Matrix Element ($K_{ij}$) integration\nRandom Sampling')
plt.grid()
plt.legend()
# Out:
# N = 100, K_ii = 0.46275450319946576, Std Dev = 0.23350651219587967
# N = 1000, K_ii = 0.4127177548322109, Std Dev = 0.04245553513796043
# N = 10000, K_ii = 0.3874734797587621, Std Dev = 0.015552181690006562
# N = 100000, K_ii = 0.3794074173534149, Std Dev = 0.004576982943216762
# N = 1000000, K_ii = 0.38877093840698823, Std Dev = 0.0014664603862205407
# N = 10000000, K_ii = 0.3882820240588162, Std Dev = 0.0004818892310991005
# N = 100000000, K_ii = 0.3879792897657618, Std Dev = 0.0001480084889488043

# %%
import Psi_1s_func as fn 
import matplotlib.pyplot as plt
import numpy as np

#Off-diagonal Kinetic Energy Matrix Element (Kij)-importance sampling

# Parameters
np.random.seed(42)
L = 7  # Integration limits
n_points_list = [10**2, 10**3, 10**4, 10**5, 10**6, 10**7,10**8]  # Varying number of points
R=1.4  #Rz=1.4

# Lists to store results
Kii_values = []
std_devs = []

# Monte Carlo integration loop for varying n_points
for n_points in n_points_list:
    Kii,std_dev=fn.important_integration(L,n_points,R)
    Kii_values.append(Kii)
    std_devs.append(std_dev)
    print(f"N = {n_points}, K_ii = {Kii}, Std Dev = {std_dev}")
   
# Plot the results
plt.figure(figsize=(8, 6))
plt.errorbar(n_points_list, Kii_values, yerr=std_devs, fmt='o-', label='Estimated $K_{ii}$')
plt.xscale('log')
plt.xlabel('Number of Points Sampled (N)')
plt.ylabel('Kinetic Energy Matrix Element ($K_{ij}$)')
plt.title('Kinetic Energy Matrix Element ($K_{ij}$) integration\nImportance Sampling')
plt.grid()
plt.legend()
# Out:
# N = 100, K_ii = 0.46275450319946576, Std Dev = 0.23350651219587967
# N = 1000, K_ii = 0.4127177548322109, Std Dev = 0.04245553513796043
# N = 10000, K_ii = 0.3874734797587621, Std Dev = 0.015552181690006562
# N = 100000, K_ii = 0.3794074173534149, Std Dev = 0.004576982943216762
# N = 1000000, K_ii = 0.38877093840698823, Std Dev = 0.0014664603862205407
# N = 10000000, K_ii = 0.3882820240588162, Std Dev = 0.0004818892310991005
# N = 100000000, K_ii = 0.3879792897657618, Std Dev = 0.0001480084889488043
